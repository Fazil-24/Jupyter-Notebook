# %%
# !unzip /content/drive/MyDrive/yolov5.zip -d /content
# Out:
# Archive:  /content/drive/MyDrive/yolov5.zip
#    creating: /content/content/yolov5/
#   inflating: /content/content/yolov5/benchmarks.py
#    creating: /content/content/yolov5/models/
#   inflating: /content/content/yolov5/models/yolov5x.yaml
#   inflating: /content/content/yolov5/models/yolov5m.yaml
#   inflating: /content/content/yolov5/models/yolov5s.yaml
#    creating: /content/content/yolov5/models/segment/
#   inflating: /content/content/yolov5/models/segment/yolov5n-seg.yaml
#   inflating: /content/content/yolov5/models/segment/yolov5s-seg.yaml
#   inflating: /content/content/yolov5/models/segment/yolov5m-seg.yaml
#   inflating: /content/content/yolov5/models/segment/yolov5l-seg.yaml
#   inflating: /content/content/yolov5/models/segment/yolov5x-seg.yaml
#    creating: /content/content/yolov5/models/__pycache__/
#   inflating: /content/content/yolov5/models/__pycache__/experimental.cpython-38.pyc
#   inflating: /content/content/yolov5/models/__pycache__/__init__.cpython-38.pyc
# ...

# %%
# %cd /content/content/yolov5
# !pwd
# Out:
# /content/content/yolov5
# /content/content/yolov5

# %%
import os
import glob as glob
import matplotlib.pyplot as plt
import cv2
import requests
import random
import numpy as np
import subprocess

# %%
def visualize(INFER_DIR):
# Visualize inference images.
    INFER_PATH = f"runs/detect/{INFER_DIR}"
    infer_images = glob.glob(f"{INFER_PATH}/*.jpg")
    print(infer_images)
    for pred_image in infer_images:
        image = cv2.imread(pred_image)
        plt.figure(figsize=(19, 16))
        plt.imshow(image[:, :, ::-1])
        plt.axis('off')
        plt.show()

# %%
def set_res_dir():
    # Directory to store results
    res_dir_count = len(glob.glob('runs/train/*'))
    print(f"Current number of result directories: {res_dir_count}")
    if TRAIN:
        RES_DIR = f"results_{res_dir_count+1}"
        print(RES_DIR)
    else:
        RES_DIR = f"results_{res_dir_count}"
    return RES_DIR

# %%
# Helper function for inference on images.
def inference(RES_DIR, data_path):
    print(RES_DIR)
    # Directory to store inference results.
    infer_dir_count = len(glob.glob('runs/detect/*'))
    print(f"Current number of inference detection directories: {infer_dir_count}")
    INFER_DIR = f"inference_{infer_dir_count+1}"
    
    # !python detect.py --weights runs/train/results_1/weights/best.pt \
    --source {data_path} --name {INFER_DIR}
    return INFER_DIR

# %%
TRAIN = False

# %%
RES_DIR = set_res_dir()
# Out:
# Current number of result directories: 1

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 14.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 60.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# cvxpy 1.2.3 requires setuptools<=64.0.2, but you have setuptools 67.4.0 which is incompatible.
# ...

# %%
IMAGE_INFER_DIR = inference(RES_DIR, '/content/pothole1.jpg')
visualize(IMAGE_INFER_DIR)
# Out:
# results_1
# Current number of inference detection directories: 1
# detect: weights=['runs/train/results_1/weights/best.pt'], source=/content/pothole1.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=inference_2, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-114-g3c0a6e6 Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/pothole1.jpg: 416x640 2 potholes, 291.3ms
# Speed: 5.7ms pre-process, 291.3ms inference, 19.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/inference_2
# ['runs/detect/inference_2/pothole1.jpg']

# %%
# !python detect.py --source '/content/pothole1.jpg' --weights 'runs/train/results_1/weights/best.pt'
# Out:
# detect: weights=['runs/train/results_1/weights/best.pt'], source=/content/pothole1.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-114-g3c0a6e6 Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/pothole1.jpg: 416x640 2 potholes, 291.1ms
# Speed: 5.0ms pre-process, 291.1ms inference, 1.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
python3 detect.py --source 0
# Out:
#   File "<ipython-input-15-8b5a0b2faad8>", line 1
#     python3 detect.py --source 0
#             ^
# SyntaxError: invalid syntax

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source '/content/pothole1.jpg'
# Out:
# detect: weights=['yolov5s.pt'], source=/content/pothole1.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-114-g3c0a6e6 Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/pothole1.jpg: 416x640 2 cars, 495.6ms
# Speed: 5.4ms pre-process, 495.6ms inference, 4.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2
